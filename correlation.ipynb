# %%
import pandas as pd
import numpy as np

df = pd.read_excel('data/variables_completas.xlsx')

df
# Out:
#      Unnamed: 0  POBTOT  POBFEM  POBMAS  P_0A2  P_0A2_F  P_0A2_M  P_3YMAS  \
# 0             0   541.0     262     279     26       10       16      515
# 1             1  4149.0    2158    1991     92       48       44     4057
# 2             2  3265.0    1621    1644    120       69       51     3145
# 3             3  2302.0    1145    1157     78       40       38     2224
# 4             4  3419.0    1788    1631    146       70       76     3273
# ..          ...     ...     ...     ...    ...      ...      ...      ...
# 541         541  2407.0    1162    1245    141       72       69     2266
# 542         542  1944.0    1018     926     48       27       21     1896
# 543         543  6841.0    3312    3529    376      197      179     6463
# 544         544  3874.0    1900    1974    127       62       65     3741
# 545         545  2022.0    1020    1002     97       54       43     1925
#
#      P_3YMAS_F  P_3YMAS_M  ...  VPH_INTER  VPH_STVP  VPH_SPMVPI  VPH_CVJ  \
# 0          252        263  ...         81        94          25       13
# 1         2110       1947  ...       1055       734         448      254
# 2         1552       1593  ...        595       353         211      125
# 3         1105       1119  ...        394       261         175       88
# 4         1718       1555  ...        960       758         792      522
# ..         ...        ...  ...        ...       ...         ...      ...
# 541       1090       1176  ...        348       243          64       54
# 542        991        905  ...        512       313         245      120
# 543       3114       3349  ...        950       608         242      155
# 544       1835       1906  ...        647       448         130       91
# 545        966        959  ...        383       251         183      100
#
#      VPH_SINRTV  VPH_SINLTC  VPH_SINCINT  VPH_SINTIC  #llamadas  GRS_num
# 0            14          15          102           9        NaN      NaN
# 1            10          10          143           0        1.0      NaN
# 2            11          39          231           3        NaN      2.0
# 3            23          44          249           8      115.0      2.0
# 4             6           9           56           0        3.0      1.0
# ..          ...         ...          ...         ...        ...      ...
# 541          34          22          305           4        NaN      NaN
# 542           4          13           88           0        1.0      NaN
# 543          49          76          511          10      336.0      3.0
# 544          21          54          381           4        NaN      3.0
# 545           5          28          184           0        NaN      NaN
#
# [546 rows x 225 columns]

# %%
correlation_matrix = df.corr()

correlation_matrix
# Out:
# /tmp/ipykernel_73277/3415491360.py:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   correlation_matrix = df.corr()
#              Unnamed: 0    POBTOT    POBFEM    POBMAS     P_0A2   P_0A2_F  \
# Unnamed: 0     1.000000  0.081201  0.075950  0.086242  0.113114  0.115038
# POBTOT         0.081201  1.000000  0.999312  0.999330  0.896746  0.895644
# POBFEM         0.075950  0.999312  1.000000  0.997284  0.890473  0.889801
# POBMAS         0.086242  0.999330  0.997284  1.000000  0.901722  0.900197
# P_0A2          0.113114  0.896746  0.890473  0.901722  1.000000  0.995272
# ...                 ...       ...       ...       ...       ...       ...
# VPH_SINLTC     0.074317  0.589717  0.580070  0.598444  0.632289  0.633042
# VPH_SINCINT    0.105844  0.705884  0.696150  0.714538  0.843014  0.836692
# VPH_SINTIC     0.066289  0.364752  0.356146  0.372756  0.443748  0.441053
# #llamadas      0.110741  0.503091  0.486490  0.518034  0.628391  0.623571
# GRS_num        0.151891  0.017527  0.002567  0.032176  0.221303  0.221750
#
#               P_0A2_M   P_3YMAS  P_3YMAS_F  P_3YMAS_M  ...  VPH_INTER  \
# Unnamed: 0   0.110461  0.080458   0.074785   0.085941  ...   0.027588
# POBTOT       0.889869  0.999125   0.997972   0.998775  ...   0.845817
# POBFEM       0.883243  0.998817   0.999091   0.997058  ...   0.852861
# POBMAS       0.895203  0.998081   0.995522   0.999121  ...   0.837726
# P_0A2        0.995468  0.884707   0.877961   0.890053  ...   0.608299
# ...               ...       ...        ...        ...  ...        ...
# VPH_SINLTC   0.625887  0.583178   0.572676   0.592684  ...   0.196619
# VPH_SINCINT  0.841480  0.692536   0.682345   0.701572  ...   0.269334
# VPH_SINTIC   0.442348  0.357717   0.348644   0.366147  ...   0.067218
# #llamadas    0.624930  0.493097   0.475016   0.509368  ...   0.044127
# GRS_num      0.219069  0.006024  -0.009710   0.021540  ...  -0.397070
#
#              VPH_STVP  VPH_SPMVPI   VPH_CVJ  VPH_SINRTV  VPH_SINLTC  \
# Unnamed: 0   0.027331   -0.011970  0.008650    0.089419    0.074317
# POBTOT       0.838499    0.559629  0.620617    0.608385    0.589717
# POBFEM       0.845953    0.571900  0.631327    0.596384    0.580070
# POBMAS       0.830013    0.546764  0.609209    0.619413    0.598444
# P_0A2        0.667346    0.326357  0.412925    0.702968    0.632289
# ...               ...         ...       ...         ...         ...
# VPH_SINLTC   0.212932   -0.114947 -0.079421    0.695043    1.000000
# VPH_SINCINT  0.395311   -0.043698  0.033833    0.773247    0.788828
# VPH_SINTIC   0.130154   -0.127695 -0.112456    0.719855    0.788906
# #llamadas   -0.142566   -0.276139 -0.262173    0.325037    0.712706
# GRS_num     -0.310191   -0.583981 -0.555333    0.290772    0.479755
#
#              VPH_SINCINT  VPH_SINTIC  #llamadas   GRS_num
# Unnamed: 0      0.105844    0.066289   0.110741  0.151891
# POBTOT          0.705884    0.364752   0.503091  0.017527
# POBFEM          0.696150    0.356146   0.486490  0.002567
# POBMAS          0.714538    0.372756   0.518034  0.032176
# P_0A2           0.843014    0.443748   0.628391  0.221303
# ...                  ...         ...        ...       ...
# VPH_SINLTC      0.788828    0.788906   0.712706  0.479755
# VPH_SINCINT     1.000000    0.592062   0.696944  0.448463
# VPH_SINTIC      0.592062    1.000000   0.455003  0.409608
# #llamadas       0.696944    0.455003   1.000000  0.608462
# GRS_num         0.448463    0.409608   0.608462  1.000000
#
# [219 rows x 219 columns]

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# Set the size for the plot
plt.figure(figsize=(15, 15))
# Square each value
correlation_matrix = np.square(correlation_matrix)

# Use seaborn to create a heatmap of the correlation matrix cmap inverted grey
sns.heatmap(correlation_matrix, xticklabels=False, yticklabels=False, cmap='gray_r')

# Show the plot
plt.title('Correlation Matrix Heatmap')
plt.show()

# %%
corr_pairs = correlation_matrix.stack()

# Exclude self-correlations (correlation of variables with themselves) which are always 1
corr_pairs = corr_pairs[corr_pairs.index.get_level_values(0) != corr_pairs.index.get_level_values(1)]

# Sorting the pairs by correlation, from highest to lowest
sorted_corr_pairs = corr_pairs.sort_values(ascending=False)

# Filtering for high correlations; here we can choose a threshold, for example, 0.9
high_correlation_threshold = 0.9
high_corr_pairs = sorted_corr_pairs[sorted_corr_pairs > high_correlation_threshold]

# Filtering for low correlations; here we can choose a threshold, for example, 0.1
low_correlation_threshold = 0.1
low_corr_pairs = sorted_corr_pairs[sorted_corr_pairs < low_correlation_threshold]

high_corr_pairs.head(20)
# Out:
# OCUPVIVPAR  POBHOG        1.000000
# P3HLINHE    P5_HLI_NHE    1.000000
# TOTHOG      TVIVPARHAB    1.000000
# TVIVPARHAB  TOTHOG        1.000000
# POBHOG      OCUPVIVPAR    1.000000
# P5_HLI_NHE  P3HLINHE      1.000000
# TOTHOG      TVIVHAB       0.999992
# TVIVPARHAB  TVIVHAB       0.999992
# TVIVHAB     TOTHOG        0.999992
#             TVIVPARHAB    0.999992
# VIVPARH_CV  TVIVPARHAB    0.999966
#             TOTHOG        0.999966
# TVIVPARHAB  VIVPARH_CV    0.999966
# TOTHOG      VIVPARH_CV    0.999966
# VIVPARH_CV  TVIVHAB       0.999955
# TVIVHAB     VIVPARH_CV    0.999955
# VPH_AGUADV  VPH_C_SERV    0.999712
# VPH_C_SERV  VPH_AGUADV    0.999712
# VPH_DSADMA  VPH_DRENAJ    0.999699
# VPH_DRENAJ  VPH_DSADMA    0.999699
# dtype: float64

# %%
# Sum all correlations for each variable
corr_sums = correlation_matrix.sum()

# Sort the correlations from highest to lowest
sorted_corr_sums = corr_sums.sort_values(ascending=False)

sorted_corr_sums.tail(10)
# Out:
# POTRAS_REL    1.030617
# VPH_S_ELEC    1.006290
# VPH_AGUAFV    1.006034
# PDER_ISTEE    1.002699
# PDER_IMSSB    1.001243
# REL_H_M       1.000064
# VPH_NDEAED    1.000003
# Unnamed: 0    1.000002
# PAFIL_PDOM    1.000000
# P3HLINHE_M    0.000000
# dtype: float64

# %%
# Plot using matplotlib the sorted_corr_sums
plt.figure(figsize=(15, 10))
plt.bar(sorted_corr_sums.index, sorted_corr_sums)
plt.xticks(rotation=90)
plt.title('Sum of Correlations')
plt.show()

# %%
# Load the Dicctionary 
path = '/home/jay/repos/futuro-con-derechos/data/diccionario_datos_ageb_urbana_19_cpv2020 - diccionario_datos_ageb_urbana_19_cpv2020.csv'
diccionario = pd.read_csv(path)

# Printing the description of the variables given the keys and the sum of the correlations
for key in sorted_corr_sums.tail(50).index:
    print(diccionario[diccionario['Mnemónico'] == key]['Indicador'].values)
    print(sorted_corr_sums[key])
# Out:
# ['Población masculina de 15 años y más sin escolaridad']
# 6.7202860257852635
# ['Población masculina de 6 a 11 años que no asiste a la escuela']
# 6.662828056379032
# ['Población masculina de 8 a 14 años que no sabe leer y escribir']
# 6.421556681022725
# ['Viviendas particulares habitadas sin línea telefónica fija ni teléfono celular']
# 6.270174312465555
# ['Población femenina de 12 a 14 años que no asiste a la escuela']
# 6.0741213589800385
# ['Población con limitación para hablar o comunicarse']
# 5.948684076146066
# ['Población femenina de 6 a 11 años que no asiste a la escuela']
# 5.438675169934515
# ['Población masculina de 60 años y más']
# 5.333883024338894
# ['Población de 60 años y más']
# 5.2991931501830205
# ['Viviendas particulares habitadas sin radio ni televisor']
# 5.162349981753693
# ['Población femenina de 5 años y más residente en otra entidad en marzo de 2015']
# 5.03264561769561
# ['Población femenina de 60 años y más']
# 5.007373630400103
# ['Población de 5 años y más residente en otra entidad en marzo de 2015']
# 4.96869212303833
# ['Población afiliada a servicios de salud en el Instituto de Salud para el Bienestar']
# 4.738347227256618
# ['Población masculina de 5 años y más residente en otra entidad en marzo de 2015']
# 4.5246100133729525
# ['Población de 65 años y más']
# 4.213471597324298
# []
# 3.870630829446041
# ['Viviendas particulares deshabitadas']
# 3.2736318270331624
# ['Población femenina de 8 a 14 años que no sabe leer y escribir']
# 3.0621541325395136
# ['Población que se considera afromexicana o afrodescendiente']
# 2.985154128608763
# ['Población masculina que se considera afromexicana o afrodescendiente']
# 2.9622574930258483
# ['Población femenina que se considera afromexicana o afrodescendiente']
# 2.9614123551065603
# ['Población de 3 años y más que habla alguna lengua indígena y no habla español']
# 2.6947712489546074
# ['Población de 5 años y más que habla alguna lengua indígena y no habla español']
# 2.6947712489546074
# ['Población femenina de 3 años y más que habla alguna lengua indígena y no habla español']
# 2.3888891733200763
# ['Población con limitación para vestirse, bañarse o comer']
# 1.8299781774741197
# ['Población afiliada a servicios de salud en el ISSSTE']
# 1.8065860100023343
# ['Viviendas particulares habitadas sin tecnologías de la información y de la comunicación (TIC)']
# 1.6300047295246336
# ['Viviendas particulares habitadas con dos cuartos']
# 1.4040276366390967
# ['Población afiliada a servicios de salud en otra institución']
# 1.3596332171888823
# ['Viviendas particulares habitadas sin ningún bien']
# 1.3545682173540008
# ['Población afiliada a servicios de salud en una institución privada']
# 1.26245826373367
# ['Viviendas particulares de uso temporal']
# 1.1740108570330243
# []
# 1.1288210355633277
# ['Viviendas particulares habitadas con piso de tierra']
# 1.074180932873622
# ['Viviendas particulares habitadas que disponen de cisterna o aljibe']
# 1.0505678640839493
# ['Viviendas particulares habitadas que no disponen de drenaje']
# 1.0451142322932352
# ['Viviendas particulares habitadas que disponen de tinaco']
# 1.0412925657879173
# ['Viviendas particulares habitadas con sólo un cuarto']
# 1.0396856499852491
# ['Viviendas particulares habitadas que disponen de letrina (pozo u hoyo)']
# 1.0388278643174114
# ['Población con otras religiones diferentes a las anteriores']
# 1.030617477497436
# ['Viviendas particulares habitadas que no disponen de energía eléctrica']
# 1.0062897597842049
# ['Viviendas particulares habitadas que no disponen de agua entubada en el ámbito de la vivienda']
# 1.0060341237738384
# ['Población afiliada a servicios de salud en el ISSSTE estatal']
# 1.0026991904599816
# ['Población afiliada a servicios de salud en el IMSS BIENESTAR']
# 1.0012425321800347
# ['Relación hombres-mujeres']
# 1.000064182772592
# ['Viviendas particulares habitadas que no disponen de energía eléctrica, agua entubada, ni drenaje']
# 1.000002695502343
# []
# 1.0000024272731394
# ['Población afiliada a servicios de salud en PEMEX, Defensa o Marina']
# 1.0000002571693412
# ['Población masculina de 3 años y más que habla alguna lengua indígena y no habla español']
# 0.0

# %%
# Printing the description of the variables given the keys and the sum of the correlations
for key in sorted_corr_sums.head(100).index:
    print(diccionario[diccionario['Mnemónico'] == key]['Indicador'].values)
    print(sorted_corr_sums[key])
# Out:
# ['Población de 3 años y más']
# 77.129570629366
# ['Población total']
# 77.09318419600726
# ['Población en hogares censales']
# 77.0842381949654
# ['Ocupantes en viviendas particulares habitadas']
# 77.0842381949654
# ['Población masculina de 3 años y más']
# 76.86078803403377
# ['Población de 5 años y más']
# 76.72533534729686
# ['Población masculina']
# 76.71623755599411
# ['Población femenina']
# 76.70427311289161
# ['Población masculina de 5 años y más']
# 76.64755525334783
# ['Población femenina de 3 años y más']
# 76.55101957581587
# ['Población femenina de 5 años y más']
# 75.90933966977164
# ['Población sin discapacidad, limitación, problema o condición mental']
# 74.91026318794196
# ['Población masculina de 12 años y más económicamente activa']
# 74.88365970653504
# ['Población masculina de 12 años y más ocupada']
# 74.85323441077466
# ['Población de 15 a 64 años']
# 74.68825349758185
# ['Población de 12 años y más casada o unida']
# 74.39579663681903
# ['Población masculina de 12 años y más']
# 73.5412634729444
# ['Población de 12 años y más económicamente activa']
# 73.52048786343951
# ['Población de 12 años y más ocupada']
# 73.29898017959664
# ['Población de 12 años y más']
# 73.15082390988096
# ['Población masculina de 5 años y más residente en la entidad en marzo de 2015']
# 72.90263078589314
# ['Población afiliada a servicios de salud']
# 72.8328822436679
# ['Población de 5 años y más residente en la entidad en marzo de 2015']
# 72.68011370270789
# ['Población con religión católica']
# 72.37167617990427
# ['Población femenina de 5 años y más residente en la entidad en marzo de 2015']
# 71.72423243689848
# ['Población femenina de 12 años y más']
# 71.72289783135142
# ['Población masculina de 15 años y más']
# 71.71927021668574
# ['Población de 15 años y más']
# 71.08149011759429
# ['Viviendas particulares habitadas que disponen de energía eléctrica']
# 70.7894966124244
# ['Viviendas particulares habitadas que disponen de televisor']
# 70.69756685513802
# ['Viviendas particulares habitadas que disponen de drenaje']
# 70.65471592260342
# ['Viviendas particulares habitadas que disponen de agua entubada en el ámbito de la vivienda']
# 70.59758856437841
# ['Viviendas particulares habitadas que disponen de excusado o sanitario']
# 70.5404805400841
# ['Viviendas particulares que disponen de drenaje y sanitario con admisión de agua']
# 70.48827046914653
# ['Viviendas particulares habitadas que disponen de energía eléctrica, agua entubada de la red pública y drenaje']
# 70.43030152492442
# ['Viviendas particulares habitadas que disponen de agua entubada y se abastecen del servicio público de agua']
# 70.35076623758445
# ['Total de hogares censales']
# 70.32961125512924
# ['Total de viviendas particulares habitadas']
# 70.32961125512924
# ['Total de viviendas particulares habitadas con características']
# 70.32646914096911
# ['Total de viviendas habitadas']
# 70.30505599316135
# ['Viviendas particulares habitadas con piso de material diferente de tierra']
# 70.02818240714302
# ['Población masculina de 18 años y más']
# 70.01343537085108
# ['Población en hogares censales con persona de referencia hombre']
# 69.93357852986907
# ['Viviendas particulares habitadas']
# 69.83469813237772
# ['Población femenina de 15 a 49 años\xa0']
# 69.69001011386965
# ['Viviendas particulares habitadas que disponen de refrigerador']
# 69.52181590444687
# ['Población femenina de 15 años y más']
# 69.33331453912419
# ['Población de 18 años y más']
# 69.03118518472488
# ['Población nacida en la entidad']
# 68.22728604567868
# ['Población femenina nacida en la entidad']
# 67.94775908967134
# ['Población masculina nacida en la entidad']
# 67.7473533793646
# ['Viviendas particulares habitadas que disponen de radio']
# 66.98733519726837
# ['Población femenina de 18 años y más']
# 66.88023135634745
# ['Viviendas particulares habitadas que disponen de teléfono celular']
# 66.83695968492248
# ['Viviendas particulares habitadas que disponen de lavadora']
# 64.78809382525945
# ['Hogares censales con persona de referencia hombre']
# 63.90768530352423
# ['Población femenina de 12 años y más económicamente activa']
# 63.35477588261034
# ['Población femenina de 12 años y más ocupada']
# 63.08895989741651
# ['Viviendas particulares habitadas con dos dormitorios y más']
# 62.5838652422079
# ['Viviendas particulares habitadas con 3 cuartos y más']
# 62.58180890379243
# ['Población femenina de 12 años y más no económicamente activa']
# 60.14227435566603
# ['Población afiliada a servicios de salud en el IMSS']
# 59.27773750040854
# ['Total de viviendas']
# 55.5816495180903
# ['Total de viviendas particulares']
# 55.32984848851989
# ['Población de 12 años y más no económicamente activa']
# 52.096102299344764
# ['Población femenina de 18 a 24 años']
# 50.73373148045376
# ['Población de 18 a 24 años']
# 50.42756844020276
# ['Población de 0 a 14 años']
# 49.647939806200014
# ['Población de 12 años y más soltera o nunca unida']
# 49.19223058144189
# ['Población con grupo religioso protestante/cristiano evangélico']
# 47.692329293897984
# ['Población de 8 a 14 años']
# 46.759661647185894
# ['Población masculina de 18 a 24 años']
# 45.86698513912614
# ['Población masculina de 8 a 14 años']
# 45.803618588380544
# ['Población femenina de 8 a 14 años']
# 45.56146385409594
# ['Población de 6 a 11 años']
# 45.37865798365718
# ['Población masculina de 6 a 11 años']
# 44.40509405543621
# ['Población femenina de 6 a 11 años']
# 44.25923156079556
# ['Población de 3 a 5 años']
# 43.62308258324389
# ['Población masculina de 3 a 5 años']
# 42.508340535608156
# ['Población de 12 a 14 años']
# 41.275026695442826
# ['Población de 0 a 2 años']
# 41.09796631522295
# ['Población femenina de 3 a 5 años']
# 41.08980960647018
# ['Población femenina de 0 a 2 años']
# 40.46608413300255
# ['Población femenina de 12 a 14 años']
# 40.22814708790288
# ['Población de 15 a 17 años']
# 40.21419776868908
# ['Población masculina de 0 a 2 años']
# 38.862005762026065
# ['Población femenina nacida en otra entidad']
# 38.4155712055708
# ['Población masculina de 12 a 14 años']
# 38.26738721196549
# ['Población femenina de 15 a 17 años']
# 38.007910738268016
# ['Población masculina de 15 a 17 años']
# 36.86528498749389
# ['Población nacida en otra entidad']
# 35.859086626026695
# ['Población femenina de 15 años y más con secundaria completa']
# 34.81795531225742
# ['Población de 15 años y más con secundaria completa']
# 33.591783276446
# ['Viviendas particulares habitadas que disponen de Internet']
# 33.419532222515585
# ['Población masculina nacida en otra entidad']
# 32.16095365551614
# ['Hogares censales con persona de referencia mujer']
# 32.105372139739046
# ['Población sin afiliación a servicios de salud']
# 31.63857826802225
# ['Población masculina de 15 años y más con secundaria completa']
# 31.635361895311092
# ['Viviendas particulares habitadas que disponen de horno de microondas']
# 30.507693130945597
# ['Población sin religión o sin adscripción religiosa']
# 30.412996479878295
